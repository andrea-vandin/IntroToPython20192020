# %% [markdown]
# # Computing and visualizing the most important words in online news

# %% [markdown]
# This example shows that functions can hide a lot of complexity.
# * E.g., we can download remote data by just invoking a function
# * In particular, in this example we will use the online service [NewsAPI](https://newsapi.org/)
#   * Which allows us to download recent online news

# %% [markdown]
# This document has been __created by Daniele Licari__ and elaborated by Andrea Vandin.

# %% [markdown]
# ## The modules we need to use

# %%
#import sys
#!{sys.executable} -m pip install newsapi-python
#!{sys.executable} -m pip install wordcloud

# %%
# integrating News API into your Python application 
from newsapi import NewsApiClient 
newsapi = NewsApiClient(api_key='345f8a0aa8c64d549fde1d8343d036f8')

# creating wordclouds into your Python application 
from wordcloud import WordCloud, STOPWORDS

# regular expression 
import re

import matplotlib.pyplot as plt

# %% [markdown]
# __NewsApiClient__ is a local client for the online service [__NewsAPI__](https://newsapi.org/) that allows you to get news from [eveywhere in the world](https://newsapi.org/sources)
# * Intuitively, an online service is like an online function running in a remote server
# * A local client is a piece of code runnning in your machine that communicates with the online service
#   * It allows you to easily interact with the online service
#   * The interaction is typically done through a set of message exchanges as prescribed by the APIs of the service
# * The argument `api_key` is a univoque identifier
#   * necessary when making requests to be identified
#   * can be obtained registering [here](https://newsapi.org/register)
#
# There exist many online services accessible with Python
# * Most of them follows this api-key approach
# * E.g. to enforce subscriptions
# * In our case, __we are using a free subscription that allows us to only get the first 250 characters from a news item__

# %% [markdown]
# ## Implementing two functions for data cleaning

# %% [markdown]
# __Stop words__ are usually the most common in any text ( like “the”, “of”, “to” and “and”),
# * They don’t tell us much about the actual content in a text
# * These are the words we want to ignore - this is our data cleaning
#
# We want to find the words that will help us differentiate a text from texts that are about different subjects.
# * __We will filter out the common (function) words__. Words that are ignored like this are known as stop words.
# * Of course, we are going to use a function for doing this

# %% [markdown]
# Furthermore, we want to ignore punctuations
# * A __regular expression__ is string able to represent many other strings that _match it_
# * We are going to use it to delete all punctuations from a string

# %%
# to remove STOPWORDS
def removeStopwords(wordlist):
    return [w for w in wordlist if (w not in STOPWORDS) and (w not in {'usa','today','verge','bbc','cnn'})]

# to remove Punctuations
def removePunctuations(txt):
    return re.sub(r'[^\w\s]','',txt)  # all non-alphanumerics are replaced with a blank space using re.

# %% [markdown]
# ## Data loading

# %% [markdown]
# We first get the most relevant articles (top 50) about coronavirus, published in usa-today
# * This looks like a normal function invokation
# * But under the hood a lot happens to contact the remote service
#
# Luckily, the function `get_everything` hides this complexity to us

# %%
json_data = newsapi.get_everything(q='coronavirus',        # All the articles that contain this word
                                    language='en',
                                    sources = 'usa-today', # The newspaper of interest
                                    #sources = 'cnn', # The newspaper of interest
                                    #sources = 'bbc-news', # The newspaper of interest
                                    #sources = 'bbc-news,the-verge'
                                    #
                                    page_size=50,           # Get 50 articles
                                    sort_by='relevancy' 
                                    )
#There exist many more parameters allowing us the ask for more articles, different sources, etc

# %% [markdown]
# The return value `json_data` is just a dictionary collecting information about the remote request

# %%
print(type(json_data))
print()
print(json_data.keys())
print()
print('The status of the request is',json_data['status'],'There are ',json_data['totalResults'],'articles matching the request.')
print('We got',len(json_data['articles']),'article')
print()
# Out:
# <class 'dict'>
#
# dict_keys(['status', 'totalResults', 'articles'])
#
# The status of the request is ok There are  2617 articles matching the request.
# We got 50 article

# %% [markdown]
# We can ignore all the metadata (i.e. the data about the remote request) and focus on the actual articles only

# %%
articles = json_data['articles'] 

#Get the content of the first article
content = articles[0]['content']
print(content)
print(len(content))
# Out:
# White House has confirmed a second coronavirus case among West Wing staff, this time in VP Mike Pence's office. President Trump addresses concerns.
# USA TODAY
# Top federal health officials will testi… [+12755 chars]
# 215

# %% [markdown]
# The unformatted content of the article is truncated to 260 chars for Developer plan users

# %%
# now let's combine the content of all the news into 'contents' variable
def combine_articles(list_of_articles):
    contents = ''
    for article in list_of_articles:
         #  check if key 'content' has Non-None value in dictionary 
        if article['content']:
            #contents += article['content']+" "
            contents += re.split('\w+…|…', article['content'])[0]+" " # using  re.split to remove the truncated word e.g. testi… [+12755 chars]
    return contents

contents = combine_articles(articles)
print(len(contents))
print(contents)
# Out:
# 8477
# White House has confirmed a second coronavirus case among West Wing staff, this time in VP Mike Pence's office. President Trump addresses concerns.
# USA TODAY
# Top federal health officials will  Small business owners share their difficult and confusing journeys in applying for the Paycheck Protection Program loan.
# USA TODAY
# Small businesses trying to get their state legislatures to force  Certain CVS Pharmacy stores will begin offering coronavirus testing in their parking lots and drive-through pharmacy lanes.
# CVS Health announced Monday that starting in May, it "will offer self- Wild animals around the world have been spotted checking out urban spaces as humans lock down to prevent the spread of coronavirus.
# Storyful
# The claim: Drops in carbon emissions arent enough to  Remdesivir is reportedly showing promise, but there's no guarantee the initial reports will lead to a commercially available treatment for COVID-19.
# USA TODAY
# The claim: China owns the patent for  The CDC recommends wearing a face mask that covers your nose and mouth when leaving your home for essentials like groceries and prescriptions. Some types of masks are not intended for reuse, but  Maria Ortega cradled a phone to her ear her children and grandchildren huddled around her as she choked out a few final words to her 74-year-old mother, Rachel Luna.
# Luna was in an ICU bed across  Working from home requires modifications to a traditional workday. The blending of responsibilities from two major areas of our lives, work and home, can be a considerable source of stress. Dr. Eric  As flu season comes to an end and allergy season starts to heat up, there may be concerns about symptoms that mimic the new coronavirus COVID-19.
# Wochit
# WOODLAND PARK, N.J.  With coronavirus  This one crisis could spell the end for a tradition held in place for hundreds of years. But if the handshake disappears, what will take its place?
# Social norms and good manners evolve to resolve  The Director of the National Institute of Allergy and Infectious Diseases, Dr. Anthony Fauci says the government is working on several potential vaccines for COVID-19. (May 12)
# AP Domestic
# There  States are lifting restrictions all around the country, but medical professionals warn that we should take small steps (if any) out of isolation. What's a person to do?
# Would dining in a half-full  Jon Bremseth passes deserted lockers when he makes his way down the empty blue-and-white halls at Barron Collier High School.
# He heads to the Naples, Florida, high school a few days each week to  Adele shared a series of reactions on Instagram to Beyonce's Coachella performance, proving once again that she is just like everyone else. Keri Lumm reports.
# Adele made a rare resurgence on social  The U.S. is currently facing a shortage of ventilators. Here's how they work and why they are so important in fighting COVID-19.
# USA TODAY
# As American doctors watched their Italian counterparts  Dr. Jessica Mumme talks about her challenge getting her own COVID-19 test
# USA TODAY
# The federal Medicare program lowballed payments for a coronavirus lab test early in the outbreak, limiting the  The White House is pushing a return to its failed experiment in relying on temperature screening of air travelers to detect coronavirus despite vehement objections from the nation's top public  The U.S. is currently facing a shortage of ventilators. Here's how they work and why they are so important in fighting COVID-19.
# USA TODAY
# A New York study suggests blood thinners may help reduce  CNN'S Chris Cuomo announced he has officially tested negative for coronavirus and has both antibodies after contracting the virus nearly a month ago.
# USA TODAY
# Chris Cuomo's wife, Cristina, has  Homeless communities are one of the most vulnerable amidst the COVID-19 pandemic, and people are on the frontlines to ensure their health and safety.
# USA TODAY
# Transgender singer and actress Mizz  CNN'S Chris Cuomo announced he has officially tested negative for coronavirus and has both antibodies after contracting the virus nearly a month ago.
# USA TODAY
# Cristina Cuomo is sharing a quick  President Trump's comments on disinfectants and sunlight being used to kill coronavirus sparked backlash on social media and with medical professionals.
# USA TODAY
# WASHINGTON A Texas wellness  The teachers of Val Vista Lakes Elementary School in Gilbert, AZ missed their students so much they orchestrated a parade to show them just how much.
# Arizona Republic
# Remember when you didn't  Entrepreneur Elon Musk and musical artist Grimes welcomed a baby boy, "X Æ A-12," to the world. Here's a possible explanation of the name.
# USA TODAY
#  Here is what preliminary data says about COVID-19 transmission between humans and pets.er third child, posed naked on the cover of Dujour Magazine. As John Basedow (@JohnBasedow) reports, the 'Keeping Up with the Kardashians' star posted the  Americans are slowly starting to leave their homes after quickly complying with social distancing and stay-at-home orders. Data suggests we are less eager to venture out than we were to hunker down.
# USA TODAY
# The claim: The Obama administration gave $3.7 million to a research institute in Wuhan, China
# The  (Photo: Getty Images)
# When Melissa Hamel is making meals, shes cutting back on the meat and bulking up on the veggies.
# Hamel, who lives in Arkansas with her partner and daughter, said shes had  R-0 may be the most important scientific term youve never heard of when it comes to stopping the coronavirus pandemic.
# USA TODAY
# The claim: Vitamins C and D have been adopted as treatment for  President Donald Trump continued to promote hydroxychloroquine as a treatment for COVID-19 Friday, despite warnings from the FDA against prescribing the malaria drug. Trump said the president of  This story was co-published with The Trace, a nonprofit newsroom covering guns in America.
# Gun stores in several states have defied orders to close their doors as the coronavirus pandemic drives  Nick Cordero's wife, Amanda Kloots, said the Broadway actor had surgery to remove his right leg because of complications from coronavirus.
# Wochit
# Nick Cordero's wife Amanda Kloots is offering a  Elon Musk and singer Grimes make their red carpet debut at the Met Gala.
# USA TODAY
# Congratulations are in order for Grimes and Elon Musk!
# The 32-year-old musical artist, whose real name is Claire  President Trump on Wednesday tapped venture capitalist and former pharmaceutical head Moncef Slaoui to head Operation Warp Speed, a White House initiative meant to quickly develop and distribute  Oldham County Judge Don Allred was sitting in his living room on a Thursday night when the state health department called.
# Oldham County located on historic Route 66 bordering New Mexico in the  The brother of the an American man being held in Moscow on suspicion of spying said on Tuesday that the charges of spying that his brother is accused of are ludicrous. (Jan. 22)
# WASHINGTON As the  As coronavirus spreads, people are getting more cautious and creative with their social interactions.
# USA TODAY
# The World Health Organization will hold its annual convention via teleconference for  Michigan residents on alert as Midland could be under 9 feet of water
# Urging residents to evacuate and warning that downtown Midland could be under 9 feet of water by Wednesday afternoon, Gov.  Last SlideNext Slide
# As educators everywhere try to figure out how to do their jobs remotely, the coronavirus pandemic has highlighted another problem facing schools across the country: the  Among the worst moments of the 1918 influenza pandemic were Philadelphia's overwhelmed morgue stacking unembalmed bodies without ice on multiple floors until storage was found, or the city resorting  Dr. Anthony Fauci told senators "it is without a doubt that there will be infections" in the fall and warned of more deaths without adequate response.
# USA TODAY
# WASHINGTON Top public health  Matthew McConaughey on 'Stay Home' PSA, future of Hollywood
# AP Domestic
# Matthew McConaughey is calling for unity during the coronavirus pandemic which he feels has been politicized.
# The Academy  Last SlideNext Slide
# The nations top federal disease agency had just started activating teams in nine states still relatively untouched by coronavirus when new orders came in last week from the

# %% [markdown]
# ## Data cleaning, manipulation and visualization

# %% [markdown]
# Now begins the funny part
# 1. Let's clean the data removing not interesting words
# 2. Let's compute the frequency of use of words
# 3. Let's visualize graphically the computed analysis - Word Cloud

# %%
# 1 cleaning data
def clean_data(contents):
    print('Before cleaning')
    print(contents[0:600])
    print()

    content_to_clean = contents.lower()
    clean_content = removePunctuations(content_to_clean).split()
    clean_content = removeStopwords(clean_content)
    
    print('After cleaning')
    print(clean_content[0:200])
    print()
    return clean_content

clean_content = clean_data(contents)
# Out:
# Before cleaning
# White House has confirmed a second coronavirus case among West Wing staff, this time in VP Mike Pence's office. President Trump addresses concerns.
# USA TODAY
# Top federal health officials will  Small business owners share their difficult and confusing journeys in applying for the Paycheck Protection Program loan.
# USA TODAY
# Small businesses trying to get their state legislatures to force  Certain CVS Pharmacy stores will begin offering coronavirus testing in their parking lots and drive-through pharmacy lanes.
# CVS Health announced Monday that starting in May, it "will offer self- Wild anima
#
# After cleaning
# ['white', 'house', 'confirmed', 'second', 'coronavirus', 'case', 'among', 'west', 'wing', 'staff', 'time', 'vp', 'mike', 'pences', 'office', 'president', 'trump', 'addresses', 'concerns', 'top', 'federal', 'health', 'officials', 'will', 'small', 'business', 'owners', 'share', 'difficult', 'confusing', 'journeys', 'applying', 'paycheck', 'protection', 'program', 'loan', 'small', 'businesses', 'trying', 'state', 'legislatures', 'force', 'certain', 'cvs', 'pharmacy', 'stores', 'will', 'begin', 'offering', 'coronavirus', 'testing', 'parking', 'lots', 'drivethrough', 'pharmacy', 'lanes', 'cvs', 'health', 'announced', 'monday', 'starting', 'may', 'will', 'offer', 'self', 'wild', 'animals', 'around', 'world', 'spotted', 'checking', 'urban', 'spaces', 'humans', 'lock', 'prevent', 'spread', 'coronavirus', 'storyful', 'claim', 'drops', 'carbon', 'emissions', 'arent', 'enough', 'remdesivir', 'reportedly', 'showing', 'promise', 'theres', 'guarantee', 'initial', 'reports', 'will', 'lead', 'commercially', 'available', 'treatment', 'covid19', 'claim', 'china', 'owns', 'patent', 'cdc', 'recommends', 'wearing', 'face', 'mask', 'covers', 'nose', 'mouth', 'leaving', 'home', 'essentials', 'groceries', 'prescriptions', 'types', 'masks', 'intended', 'reuse', 'maria', 'ortega', 'cradled', 'phone', 'ear', 'children', 'grandchildren', 'huddled', 'around', 'choked', 'final', 'words', '74yearold', 'mother', 'rachel', 'luna', 'luna', 'icu', 'bed', 'across', 'working', 'home', 'requires', 'modifications', 'traditional', 'workday', 'blending', 'responsibilities', 'two', 'major', 'areas', 'lives', 'work', 'home', 'considerable', 'source', 'stress', 'dr', 'eric', 'flu', 'season', 'comes', 'end', 'allergy', 'season', 'starts', 'heat', 'may', 'concerns', 'symptoms', 'mimic', 'new', 'coronavirus', 'covid19', 'wochit', 'woodland', 'park', 'nj', 'coronavirus', 'one', 'crisis', 'spell', 'end', 'tradition', 'held', 'place', 'hundreds', 'years', 'handshake', 'disappears', 'will', 'take', 'place', 'social', 'norms', 'good', 'manners', 'evolve', 'resolve', 'director']

# %%
# 2 computing word-frequency pairs
def analyze_data(clean_content):
    wordcount = {}
    for w in clean_content:
        if w in wordcount:
            wordcount[w] += 1
        else:
            wordcount[w] = 1
    return wordcount

wordcount = analyze_data(clean_content)
print(wordcount)
# Out:
# {'white': 3, 'house': 3, 'confirmed': 1, 'second': 1, 'coronavirus': 17, 'case': 1, 'among': 2, 'west': 1, 'wing': 1, 'staff': 1, 'time': 1, 'vp': 1, 'mike': 1, 'pences': 1, 'office': 1, 'president': 5, 'trump': 4, 'addresses': 1, 'concerns': 2, 'top': 4, 'federal': 3, 'health': 6, 'officials': 1, 'will': 7, 'small': 3, 'business': 1, 'owners': 1, 'share': 1, 'difficult': 1, 'confusing': 1, 'journeys': 1, 'applying': 1, 'paycheck': 1, 'protection': 1, 'program': 2, 'loan': 1, 'businesses': 1, 'trying': 1, 'state': 2, 'legislatures': 1, 'force': 1, 'certain': 1, 'cvs': 2, 'pharmacy': 2, 'stores': 2, 'begin': 1, 'offering': 2, 'testing': 1, 'parking': 1, 'lots': 1, 'drivethrough': 1, 'lanes': 1, 'announced': 3, 'monday': 1, 'starting': 2, 'may': 6, 'offer': 1, 'self': 1, 'wild': 1, 'animals': 1, 'around': 3, 'world': 3, 'spotted': 1, 'checking': 1, 'urban': 1, 'spaces': 1, 'humans': 2, 'lock': 1, 'prevent': 1, 'spread': 1, 'storyful': 1, 'claim': 4, 'drops': 1, 'carbon': 1, 'emissions': 1, 'arent': 1, 'enough': 1, 'remdesivir': 1, 'reportedly': 1, 'showing': 1, 'promise': 1, 'theres': 1, 'guarantee': 1, 'initial': 1, 'reports': 3, 'lead': 1, 'commercially': 1, 'available': 1, 'treatment': 3, 'covid19': 9, 'china': 2, 'owns': 1, 'patent': 1, 'cdc': 1, 'recommends': 1, 'wearing': 1, 'face': 1, 'mask': 1, 'covers': 1, 'nose': 1, 'mouth': 1, 'leaving': 1, 'home': 4, 'essentials': 1, 'groceries': 1, 'prescriptions': 1, 'types': 1, 'masks': 1, 'intended': 1, 'reuse': 1, 'maria': 1, 'ortega': 1, 'cradled': 1, 'phone': 1, 'ear': 1, 'children': 1, 'grandchildren': 1, 'huddled': 1, 'choked': 1, 'final': 1, 'words': 1, '74yearold': 1, 'mother': 1, 'rachel': 1, 'luna': 2, 'icu': 1, 'bed': 1, 'across': 2, 'working': 2, 'requires': 1, 'modifications': 1, 'traditional': 1, 'workday': 1, 'blending': 1, 'responsibilities': 1, 'two': 1, 'major': 1, 'areas': 1, 'lives': 2, 'work': 3, 'considerable': 1, 'source': 1, 'stress': 1, 'dr': 4, 'eric': 1, 'flu': 1, 'season': 2, 'comes': 2, 'end': 2, 'allergy': 2, 'starts': 1, 'heat': 1, 'symptoms': 1, 'mimic': 1, 'new': 4, 'wochit': 2, 'woodland': 1, 'park': 1, 'nj': 1, 'one': 2, 'crisis': 1, 'spell': 1, 'tradition': 1, 'held': 2, 'place': 2, 'hundreds': 1, 'years': 1, 'handshake': 1, 'disappears': 1, 'take': 2, 'social': 5, 'norms': 1, 'good': 1, 'manners': 1, 'evolve': 1, 'resolve': 1, 'director': 1, 'national': 1, 'institute': 2, 'infectious': 1, 'diseases': 1, 'anthony': 2, 'fauci': 2, 'says': 2, 'government': 1, 'several': 2, 'potential': 1, 'vaccines': 1, '12': 1, 'ap': 2, 'domestic': 2, 'states': 3, 'lifting': 1, 'restrictions': 1, 'country': 2, 'medical': 2, 'professionals': 2, 'warn': 1, 'steps': 1, 'isolation': 1, 'whats': 1, 'person': 1, 'dining': 1, 'halffull': 1, 'jon': 1, 'bremseth': 1, 'passes': 1, 'deserted': 1, 'lockers': 1, 'makes': 1, 'way': 1, 'empty': 1, 'blueandwhite': 1, 'halls': 1, 'barron': 1, 'collier': 1, 'high': 2, 'school': 3, 'heads': 1, 'naples': 1, 'florida': 1, 'days': 1, 'week': 2, 'adele': 2, 'shared': 1, 'series': 1, 'reactions': 1, 'instagram': 1, 'beyonces': 1, 'coachella': 1, 'performance': 1, 'proving': 1, 'everyone': 1, 'keri': 1, 'lumm': 1, 'made': 1, 'rare': 1, 'resurgence': 1, 'us': 2, 'currently': 2, 'facing': 3, 'shortage': 2, 'ventilators': 2, 'heres': 3, 'important': 3, 'fighting': 2, 'american': 2, 'doctors': 1, 'watched': 1, 'italian': 1, 'counterparts': 1, 'jessica': 1, 'mumme': 1, 'talks': 1, 'challenge': 1, 'getting': 2, 'test': 2, 'medicare': 1, 'lowballed': 1, 'payments': 1, 'lab': 1, 'early': 1, 'outbreak': 1, 'limiting': 1, 'pushing': 1, 'return': 1, 'failed': 1, 'experiment': 1, 'relying': 1, 'temperature': 1, 'screening': 1, 'air': 1, 'travelers': 1, 'detect': 1, 'despite': 2, 'vehement': 1, 'objections': 1, 'nations': 2, 'public': 2, 'york': 1, 'study': 1, 'suggests': 2, 'blood': 1, 'thinners': 1, 'help': 1, 'reduce': 1, 'cnns': 2, 'chris': 3, 'cuomo': 3, 'officially': 2, 'tested': 2, 'negative': 2, 'antibodies': 2, 'contracting': 2, 'virus': 2,  ...

# %%
# 3 visualizing the analysisis in a Word Cloud
def visualize_data(wordcount):
    wc = WordCloud(width=1200,height=600, background_color='white').generate_from_frequencies(wordcount)
    plt.figure(figsize=(20,10))
    plt.imshow(wc)
    plt.axis("off")
    plt.show()

visualize_data(wordcount)

# %% [markdown]
# ## Let's put everything in a function, so that we can run it easily for different sources

# %%
#import sys
#!{sys.executable} -m pip install newsapi-python
#!{sys.executable} -m pip install wordcloud

# integrating News API into your Python application 
from newsapi import NewsApiClient 
newsapi = NewsApiClient(api_key='345f8a0aa8c64d549fde1d8343d036f8')

# creating wordclouds into your Python application 
from wordcloud import WordCloud, STOPWORDS

# regular expression 
import re

import matplotlib.pyplot as plt

def make_world_cloud(query,sour,p_size):
    json_data = newsapi.get_everything(q=query,           # All the articles that contain this word
                                       language='en',
                                       sources=sour,      # The newspaper of interest
                                       page_size=p_size,  # Get 50 articles
                                       sort_by='relevancy'   
                                    )
    
    #Combine the articles in one data
    contents = combine_articles(json_data['articles'])
    
    # 1 cleaning data
    clean_content = clean_data(contents)

    # 2 computing word-frequency pairs
    wordcount = analyze_data(clean_content)
 
    # 3 visualizing the analysisis in a Word Cloud
    visualize_data(wordcount)

# %%
make_world_cloud('coronavirus','the-verge',50)
# Out:
# Before cleaning
# Tesla is reopening its California car factory against Alameda Countys wishes
# Tesla CEO Elon Musk has confirmed that hes reopening his companys car factory in California in violation of a local  Carnegie Robotics retrofitted the airports floor-scrubbing robots with UV lights
# A UV scrubber at Pittsburgh International Airport.
# Photo: Pittsburgh International Airport
# Pittsburgh  Even as it beat its revenue expectations in Q2
# Illustration by Alex Castro / The Verge
# Qualcomm expects smartphone shipments to fall 30 percent in the comings months due to the coronavirus  Demands include better cle
#
# After cleaning
# ['tesla', 'reopening', 'california', 'car', 'factory', 'alameda', 'countys', 'wishes', 'tesla', 'ceo', 'elon', 'musk', 'confirmed', 'hes', 'reopening', 'companys', 'car', 'factory', 'california', 'violation', 'local', 'carnegie', 'robotics', 'retrofitted', 'airports', 'floorscrubbing', 'robots', 'uv', 'lights', 'uv', 'scrubber', 'pittsburgh', 'international', 'airport', 'photo', 'pittsburgh', 'international', 'airport', 'pittsburgh', 'even', 'beat', 'revenue', 'expectations', 'q2', 'illustration', 'alex', 'castro', 'qualcomm', 'expects', 'smartphone', 'shipments', 'fall', '30', 'percent', 'comings', 'months', 'due', 'coronavirus', 'demands', 'include', 'better', 'cleaning', 'services', '14day', 'shutdowns', 'affected', 'locations', 'illustration', 'alex', 'castro', 'may', '1st', 'workers', 'amazon', 'whole', 'foods', 'instacart', 'fedex', 'target', 'senators', 'will', 'back', 'washington', 'monday', 'us', 'capitol', 'joint', 'statement', 'saturday', 'house', 'speaker', 'nancy', 'pelosi', 'dca', 'senate', 'majority', 'leader', 'mitch', 'mcconnell', 'rky', 'declined', 'president', 'company', 'latest', 'discover', 'deliveries', 'help', 'sidestep', 'restrictions', 'nonessential', 'travel', 'cruise', 'selfdriving', 'subsidiary', 'general', 'motors', 'brought', 'amazon', 'shut', 'six', 'warehouses', 'april', 'illustration', 'alex', 'castro', 'amazon', 'reopening', 'six', 'distribution', 'centers', 'france', 'beginning', 'according', 'reporter', 'patience', 'youve', 'got', 'cheaper', 'ride', 'illustration', 'alex', 'castro', 'region', 'stayathome', 'guidelines', 'best', 'avoid', 'using', 'rideshare', 'apps', 'uber', 'apple', 'watch', 'airpods', 'sales', 'devices', 'illustration', 'alex', 'castro', 'apple', 'reported', 'second', 'quarter', 'earnings', 'showed', 'resilient', 'growth', 'production', 'isnt', 'affected', 'yet', 'image', 'gmc', 'general', 'motors', 'delaying', 'upcoming', 'reveal', 'new', 'allelectric', 'hummer', 'truck', 'originally', 'scheduled', 'may', '20th', 'covid19', 'twoweek', 'extension', '2', 'per', 'hour', 'wage', 'increase', 'illustration', 'alex', 'castro', 'amazon', 'extending', 'increase']

# %%
make_world_cloud('coronavirus','bbc-news',50)
# Out:
# Before cleaning
# Image copyrightAFP
# World Health Organization (WHO) member states have agreed to set up an independent inquiry into the global response to the coronavirus pandemic.
# The resolution, approved  Image copyrightWe Are Covert
# Researchers in the US and UK have identified hundreds of mutations to the virus which causes the disease Covid-19.
# But none has yet established what this will mean  Media captionMichigan protestors decry Covid-19 state of emergency
# Gun-toting protesters against Michigan's coronavirus lockdown have rallied in the state capitol building.
# Hundreds of  Image copyrightAFPImag
#
# After cleaning
# ['image', 'copyrightafp', 'world', 'health', 'organization', 'member', 'states', 'agreed', 'set', 'independent', 'inquiry', 'global', 'response', 'coronavirus', 'pandemic', 'resolution', 'approved', 'image', 'copyrightwe', 'covert', 'researchers', 'us', 'uk', 'identified', 'hundreds', 'mutations', 'virus', 'causes', 'disease', 'covid19', 'none', 'yet', 'established', 'will', 'mean', 'media', 'captionmichigan', 'protestors', 'decry', 'covid19', 'state', 'emergency', 'guntoting', 'protesters', 'michigans', 'coronavirus', 'lockdown', 'rallied', 'state', 'capitol', 'building', 'hundreds', 'image', 'copyrightafpimage', 'caption', 'performance', 'artist', 'dubbed', 'tanzanian', 'joker', 'raising', 'awareness', 'virus', 'videos', 'night', 'burials', 'circulating', 'social', 'media', 'image', 'copyrighteunice', 'mwabiliimage', 'caption', 'eunice', 'mwabili', 'works', 'private', 'hospital', 'kenyan', 'capital', 'kenyan', 'nurse', 'found', 'shunned', 'harassed', 'prepared', 'patient', 'professional', 'photographers', 'lockdown', 'uk', 'mali', 'costa', 'rica', 'philippines', 'elsewhere', 'taken', 'shots', 'children', 'lockdown', 'image', 'copyrightharis', 'calkic', 'unicef', 'unicef', 'uk', 'image', 'copyrightcarl', 'courtgetty', 'imagesimage', 'caption', 'japans', 'famously', 'busy', 'pedestrian', 'crossings', 'lie', 'empty', 'japan', 'lockdown', 'question', 'ive', 'asked', 'numerous', 'times', 'friends', 'image', 'copyrightmiguel', 'fajardo', 'miguel', 'fajardo', 'coffee', 'farmer', 'western', 'colombia', 'spent', 'last', 'eight', 'years', 'trying', 'rebuild', 'familys', 'fortunes', 'father', 'went', 'bankrupt', 'now', 'image', 'copyrightsenaida', 'ngimage', 'caption', 'teenagers', 'senaida', 'ng', 'toronto', 'taking', 'part', 'proms', 'online', 'many', 'high', 'school', 'students', 'going', 'prom', 'rite', 'passage', 'highlight', 'six', 'positive', 'tests', 'coronavirus', 'across', 'three', 'premier', 'league', 'clubs', 'sunday', 'monday', 'top', 'flight', 'prepares', 'resume', 'june', 'unnamed', 'players', 'staff', 'tested', 'image', 'copyrightafpimage', 'caption', 'prison', 'located', 'villavicencio', '100km', 'southeast', 'bogotá', 'director', 'prison', 'colombian']
